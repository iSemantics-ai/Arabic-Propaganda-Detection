# %%
import re
import emoji
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

# %%
# we are trying to match the format of this df to concat all later

prop_df = pd.read_json("../data/processed/propaganda.json")
prop_df.head()
# Out:
#                tweetid                                        userid  \
# 0  1161436140945195008                                     392352672
# 1   764273648496742400                                    4708503082
# 2   783000454963822592                                    4567368507
# 3   533615110539841538  xKG+qL9l7ousztBAlj8iQZm78XodFiOT+aZ9PrhzkUo=
# 4   511880965892087808  xBo+HezLTB78P+7p8upU8pqHohl9wdTT1yGUaJWa2ls=
#
#                               user_display_name  \
# 0                                  نجديه عذيه .
# 1      ْ‏ོ جود العبداللّهہ|| ོالتنبيهات ما توصل
# 2                            أملي بالله كبير^_^
# 3  xKG+qL9l7ousztBAlj8iQZm78XodFiOT+aZ9PrhzkUo=
# 4  xBo+HezLTB78P+7p8upU8pqHohl9wdTT1yGUaJWa2ls=
#
#                                user_screen_name  \
# 0                                       Ksa_FO1
# 1                                         j06__
# 2                                    khoo23khoo
# 3  xKG+qL9l7ousztBAlj8iQZm78XodFiOT+aZ9PrhzkUo=
# 4  xBo+HezLTB78P+7p8upU8pqHohl9wdTT1yGUaJWa2ls=
#
#            user_reported_location  \
# 0                نجد العذيه للدعم
# 1                            None
# 2  ومازال حسن ظني بك يا ربُ جميلٌ
# 3       في جنة الخلد ان شاء الله
# 4                            None
#
#                             user_profile_description  follower_count  \
# 0  مابادل اقل من ٥ الاف ولا أقبل المقدم بدون طلب ...           70616
# 1  ‏‏‏‏‏‏‏‏‏‏‏إنه يستجيب منذُ أن دعوُت ولگِن يُدب...           60061
# 2  ❇️اللهم أسترني فوق الأرض و تحت الأرض ويوم العر...           15244
# 3  حساب خاص صدقه جاريه للمرحوم بإذن الله وليد مشع...             282
# 4  ‏‏‏‏‏‏‏بكالوريوس التربية في الآداب\nجامعة المل...            2422
#
#    following_count  account_creation_date  \
# 0            52577          1318723200000
# 1             2617          1451865600000
# 2             8957          1450742400000
# 3               14          1362268800000
# 4              509          1338940800000
#
#                                           tweet_text  is_retweet  quote_count  \
# 0  RT @GROB_07: #حـسـآب_تـمــيزة_بـتـفـاعـل 💫\n⠀┈...        True            0
# 1  اللهم اكثر من امثالي ليعم الخير و تعم السعادة ...       False            0
# 2  RT @Ana5lod: @mohommad120\n#بصائر_مع_محمد\n\n١...        True            0
# 3  إن هذه القبور مملوءة ظلمة على أهلها وإن الله ع...       False            0
# 4  (يا قومنا أجيبوا داعي الله وآمنوا به يغفر لكم ...       False            0
#
#    reply_count  like_count  retweet_count  hashtags  urls  user_mentions  \
# 0            0           0              0         3     0              2
# 1            0           0              0         1     0              0
# 2            0           0              0         1     0              3
# 3            0           0              1         1     0              0
# 4            0           0              0         1     1              0
#
#                                                 text
# 0  RT : حـسـآب تـمــيزة بـتـفـاعـل ⠀┈┉━◈♔♚♔◈━┅┄ ن...
# 1  اللهم اكثر من امثالي ليعم الخير و تعم السعادة ...
# 2  RT : بصائر مع محمد ١ النيه،إزالةالموانع،الوضوء...
# 3  إن هذه القبور مملوءة ظلمة على أهلها وإن الله ع...
# 4  (يا قومنا أجيبوا داعي الله وآمنوا به يغفر لكم ...

# %%
prop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56000 entries, 0 to 55999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   56000 non-null  int64
#  1   userid                    56000 non-null  object
#  2   user_display_name         56000 non-null  object
#  3   user_screen_name          56000 non-null  object
#  4   user_reported_location    36366 non-null  object
#  5   user_profile_description  51749 non-null  object
#  6   follower_count            56000 non-null  int64
#  7   following_count           56000 non-null  int64
#  8   account_creation_date     56000 non-null  int64
#  9   tweet_text                56000 non-null  object
#  10  is_retweet                56000 non-null  bool
#  11  quote_count               56000 non-null  int64
#  12  reply_count               56000 non-null  int64
#  13  like_count                56000 non-null  int64
#  14  retweet_count             56000 non-null  int64
#  15  hashtags                  56000 non-null  int64
#  16  urls                      56000 non-null  int64
#  17  user_mentions             56000 non-null  int64
#  18  text                      56000 non-null  object
# dtypes: bool(1), int64(11), object(7)
# memory usage: 8.2+ MB

# %%
import glob

paths = glob.glob('../data/raw/collected_gen/univ/*Tweet*.csv')
paths
# Out:
# ['../data/raw/collected_gen/univ\\UniverstiestTweetFigure.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestTweetGeneral.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestTweetSalah.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestTweetSocial.csv',
#  '../data/raw/collected_gen/univ\\UnivTweetSport.csv']

# %%
dfs = [pd.read_csv(f) for f in paths]

# %%
# df1 = pd.read_csv("../data/raw/sports_tweets.csv")
df1 = pd.concat(dfs, ignore_index=True)
df1.head()
# Out:
#       author_id possibly_sensitive                created_at  \
# 0  1.171063e+18              False  2021-10-24T12:26:07.000Z
# 1  1.171056e+18              False  2021-10-02T21:59:59.000Z
# 2  3.062775e+07              False  2021-07-08T11:59:34.000Z
# 3  1.171056e+18              False  2021-05-24T16:43:45.000Z
# 4  1.171063e+18              False  2021-04-29T16:34:16.000Z
#
#                source  conversation_id            id  \
# 0  Twitter for iPhone     1.452250e+18  1.452250e+18
# 1     Twitter Web App     1.444422e+18  1.444422e+18
# 2      Hootsuite Inc.     1.413105e+18  1.413105e+18
# 3  Twitter for iPhone     1.396870e+18  1.396870e+18
# 4  Twitter for iPhone     1.387796e+18  1.387807e+18
#
#                                                 text lang  \
# 0  سمو رئيس اللجنة الأولمبية السعودية  الأمير عبد...   ar
# 1  تركي آل الشيخ يوقّع روايته الأولى في #معرض_الر...   ar
# 2  رئيس "هيئة الترفيه": قطاع الترفيه سيكون منافسا...   ar
# 3  الرئيس المصري يستقبل المستشار تركي آل الشيخ.\n...   ar
# 4  🎥 \nالشيخ منصور بن زايد آل نهيان يستقبل سمو ال...   ar
#
#                                    entities.hashtags  \
# 0   [{'start': 244, 'end': 254, 'tag': 'واس_رياضي'}]
# 1  [{'start': 37, 'end': 63, 'tag': 'معرض_الرياض_...
# 2  [{'start': 105, 'end': 112, 'tag': 'عقارات'}, ...
# 3       [{'start': 69, 'end': 77, 'tag': 'واس_عام'}]
# 4   [{'start': 105, 'end': 115, 'tag': 'واس_رياضي'}]
#
#                                 entities.annotations  ...  \
# 0  [{'start': 43, 'end': 66, 'probability': 0.743...  ...
# 1  [{'start': 0, 'end': 12, 'probability': 0.8053...  ...
# 2  [{'start': 6, 'end': 17, 'probability': 0.6134...  ...
# 3  [{'start': 30, 'end': 42, 'probability': 0.850...  ...
# 4  [{'start': 10, 'end': 31, 'probability': 0.757...  ...
#
#   public_metrics.like_count public_metrics.quote_count  \
# 0                       4.0                        0.0
# 1                     177.0                       54.0
# 2                      31.0                        3.0
# 3                     978.0                        9.0
# 4                       3.0                        0.0
#
#                                    referenced_tweets  in_reply_to_user_id  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4  [{'type': 'replied_to', 'id': '138779596211502...         1.171063e+18
#
#    entities.mentions  users tweets  places geo.place_id attachments.poll_ids
# 0                NaN    NaN    NaN     NaN          NaN                  NaN
# 1                NaN    NaN    NaN     NaN          NaN                  NaN
# 2                NaN    NaN    NaN     NaN          NaN                  NaN
# 3                NaN    NaN    NaN     NaN          NaN                  NaN
# 4                NaN    NaN    NaN     NaN          NaN                  NaN
#
# [5 rows x 24 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9792 entries, 0 to 9791
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   author_id                     9787 non-null   float64
#  1   possibly_sensitive            9787 non-null   object
#  2   created_at                    9787 non-null   object
#  3   source                        9787 non-null   object
#  4   conversation_id               9787 non-null   float64
#  5   id                            9787 non-null   float64
#  6   text                          9787 non-null   object
#  7   lang                          9787 non-null   object
#  8   entities.hashtags             9449 non-null   object
#  9   entities.annotations          2989 non-null   object
#  10  entities.urls                 8689 non-null   object
#  11  attachments.media_keys        7556 non-null   object
#  12  public_metrics.retweet_count  9787 non-null   float64
#  13  public_metrics.reply_count    9787 non-null   float64
#  14  public_metrics.like_count     9787 non-null   float64
#  15  public_metrics.quote_count    9787 non-null   float64
#  16  referenced_tweets             1280 non-null   object
#  17  in_reply_to_user_id           261 non-null    float64
#  18  entities.mentions             1233 non-null   object
#  19  users                         5 non-null      object
#  20  tweets                        5 non-null      object
#  21  places                        2 non-null      object
#  22  geo.place_id                  51 non-null     object
#  23  attachments.poll_ids          2 non-null      object
# dtypes: float64(8), object(16)
# memory usage: 1.8+ MB

# %%
df1 = df1.dropna(subset=['text'])

# %%
is_retweet = []

for ref_tweet in df1.referenced_tweets.values:
    if not pd.isna(ref_tweet) and not ref_tweet.isdigit():
        is_retweet.append(eval(ref_tweet)[0]["type"] == "retweeted")
    else:
        is_retweet.append(False)

df1["is_retweet"] = is_retweet

# %%
col_rename = {
    "id": "tweetid",
    "text": "tweet_text",
    "created_at": "tweet_time",
    "author_id": "userid",
    "entities.urls": "urls",
    "entities.hashtags": "hashtags",
    "public_metrics.retweet_count": "retweet_count",
    "public_metrics.reply_count": "reply_count",
    "public_metrics.like_count": "like_count",
    "public_metrics.quote_count": "quote_count",
    "entities.mentions": "user_mentions",
    "is_retweet": "is_retweet",
}

df1.rename(columns=col_rename, inplace=True)
df1 = df1[col_rename.values()]
df1.head()
# Out:
#         tweetid                                         tweet_text  \
# 0  1.452250e+18  سمو رئيس اللجنة الأولمبية السعودية  الأمير عبد...
# 1  1.444422e+18  تركي آل الشيخ يوقّع روايته الأولى في #معرض_الر...
# 2  1.413105e+18  رئيس "هيئة الترفيه": قطاع الترفيه سيكون منافسا...
# 3  1.396870e+18  الرئيس المصري يستقبل المستشار تركي آل الشيخ.\n...
# 4  1.387807e+18  🎥 \nالشيخ منصور بن زايد آل نهيان يستقبل سمو ال...
#
#                  tweet_time        userid  \
# 0  2021-10-24T12:26:07.000Z  1.171063e+18
# 1  2021-10-02T21:59:59.000Z  1.171056e+18
# 2  2021-07-08T11:59:34.000Z  3.062775e+07
# 3  2021-05-24T16:43:45.000Z  1.171056e+18
# 4  2021-04-29T16:34:16.000Z  1.171063e+18
#
#                                                 urls  \
# 0  [{'start': 255, 'end': 278, 'url': 'https://t....
# 1  [{'start': 65, 'end': 88, 'url': 'https://t.co...
# 2  [{'start': 178, 'end': 201, 'url': 'https://t....
# 3  [{'start': 45, 'end': 68, 'url': 'https://t.co...
# 4  [{'start': 116, 'end': 139, 'url': 'https://t....
#
#                                             hashtags  retweet_count  \
# 0   [{'start': 244, 'end': 254, 'tag': 'واس_رياضي'}]            4.0
# 1  [{'start': 37, 'end': 63, 'tag': 'معرض_الرياض_...           71.0
# 2  [{'start': 105, 'end': 112, 'tag': 'عقارات'}, ...           20.0
# 3       [{'start': 69, 'end': 77, 'tag': 'واس_عام'}]          321.0
# 4   [{'start': 105, 'end': 115, 'tag': 'واس_رياضي'}]            3.0
#
#    reply_count  like_count  quote_count user_mentions  is_retweet
# 0          1.0         4.0          0.0           NaN       False
# 1        174.0       177.0         54.0           NaN       False
# 2         45.0        31.0          3.0           NaN       False
# 3        105.0       978.0          9.0           NaN       False
# 4          1.0         3.0          0.0           NaN       False

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9787 entries, 0 to 9791
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweetid        9787 non-null   float64
#  1   tweet_text     9787 non-null   object
#  2   tweet_time     9787 non-null   object
#  3   userid         9787 non-null   float64
#  4   urls           8689 non-null   object
#  5   hashtags       9449 non-null   object
#  6   retweet_count  9787 non-null   float64
#  7   reply_count    9787 non-null   float64
#  8   like_count     9787 non-null   float64
#  9   quote_count    9787 non-null   float64
#  10  user_mentions  1233 non-null   object
#  11  is_retweet     9787 non-null   bool
# dtypes: bool(1), float64(6), object(5)
# memory usage: 927.1+ KB

# %%
prop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56000 entries, 0 to 55999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   56000 non-null  int64
#  1   userid                    56000 non-null  object
#  2   user_display_name         56000 non-null  object
#  3   user_screen_name          56000 non-null  object
#  4   user_reported_location    36366 non-null  object
#  5   user_profile_description  51749 non-null  object
#  6   follower_count            56000 non-null  int64
#  7   following_count           56000 non-null  int64
#  8   account_creation_date     56000 non-null  int64
#  9   tweet_text                56000 non-null  object
#  10  is_retweet                56000 non-null  bool
#  11  quote_count               56000 non-null  int64
#  12  reply_count               56000 non-null  int64
#  13  like_count                56000 non-null  int64
#  14  retweet_count             56000 non-null  int64
#  15  hashtags                  56000 non-null  int64
#  16  urls                      56000 non-null  int64
#  17  user_mentions             56000 non-null  int64
#  18  text                      56000 non-null  object
# dtypes: bool(1), int64(11), object(7)
# memory usage: 8.2+ MB

# %%
paths = glob.glob('../data/raw/collected_gen/univ/*User*.csv')
paths
# Out:
# ['../data/raw/collected_gen/univ\\UniverstiestUsersFigure.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestUsersGeneral.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestUsersSalah.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestUsersSocial.csv',
#  '../data/raw/collected_gen/univ\\UniverstiestUsersSport.csv']

# %%
dfs = [pd.read_csv(f, lineterminator='\n') for f in paths]

# %%
# df2 = pd.read_csv("../data/raw/sports_users.csv")
df2 = pd.concat(dfs, ignore_index=True)
df2.head()
# Out:
#                                          description                     name  \
# 0        حساب يهتم بأخبار الرياضة المحلية والعالمية.              واس الرياضي
# 1  حساب يهتم بالشأن العام على المستويين المحلي وا...                واس العام
# 2  أرقام شركة متخصصة في نشر المعلومات الاقتصادية ...      بوابة أرقام المالية
# 3  الحساب الرسمي | Official Account of King Faisa...         جامعة الملك فيصل
# 4  خدمات بنكية رقمية #وأنت_في_مكانك ✨ | لفتح حساب...  البنك السعودي للاستثمار
#
#                                    profile_image_url                      url  \
# 0  https://pbs.twimg.com/profile_images/131274593...  https://t.co/71DZXnWjwI
# 1  https://pbs.twimg.com/profile_images/151794435...  https://t.co/zMWBLahSfG
# 2  https://pbs.twimg.com/profile_images/133080027...  https://t.co/rRX3PrBugu
# 3  https://pbs.twimg.com/profile_images/149866758...  https://t.co/hDhCttbgRW
# 4  https://pbs.twimg.com/profile_images/149781560...  https://t.co/XjDmlG7EgE
#
#                     id      username                created_at  protected  \
# 0  1171062925488001025      SPA_Spor  2019-09-09T14:09:06.000Z      False
# 1  1171056150999158791    SPAregions  2019-09-09T13:42:06.000Z      False
# 2             30627754        Argaam  2009-04-12T09:21:19.000Z      False
# 3            208523378  KFUniversity  2010-10-27T12:46:19.000Z      False
# 4            441650981      SAIBLIVE  2011-12-20T08:54:52.000Z      False
#
#    verified  public_metrics.followers_count  public_metrics.following_count  \
# 0      True                          158216                               8
# 1      True                         2165525                               8
# 2      True                          544108                               7
# 3      True                          274829                              19
# 4      True                         1062368                               1
#
#    public_metrics.tweet_count  public_metrics.listed_count  \
# 0                       18252                          493
# 1                       52420                         2031
# 2                      182223                         2856
# 3                       20205                          403
# 4                      141149                          528
#
#                                    entities.url.urls  \
# 0  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 1  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 2  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 3  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 4  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
#
#                         location  \
# 0                            NaN
# 1                         الرياض
# 2        Kingdom of Saudi Arabia
# 3  Ahsa, Kingdom of Saudi Arabia
# 4                         Riyadh
#
#                            entities.description.urls  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'start': 114, 'end': 137, 'url': 'https://t....
# 3                                                NaN
# 4  [{'start': 48, 'end': 71, 'url': 'https://t.co...
#
#                        entities.description.mentions  pinned_tweet_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  [{'start': 157, 'end': 168, 'username': 'Argaa...              NaN
# 3                                                NaN     1.559553e+18
# 4                                                NaN     1.535729e+18
#
#                        entities.description.hashtags
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'start': 18, 'end': 32, 'tag': 'وأنت_في_مكان...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   description                     1204 non-null   object
#  1   name                            1212 non-null   object
#  2   profile_image_url               1212 non-null   object
#  3   url                             1156 non-null   object
#  4   id                              1212 non-null   int64
#  5   username                        1212 non-null   object
#  6   created_at                      1212 non-null   object
#  7   protected                       1212 non-null   bool
#  8   verified                        1212 non-null   bool
#  9   public_metrics.followers_count  1212 non-null   int64
#  10  public_metrics.following_count  1212 non-null   int64
#  11  public_metrics.tweet_count      1212 non-null   int64
#  12  public_metrics.listed_count     1212 non-null   int64
#  13  entities.url.urls               1156 non-null   object
#  14  location                        1108 non-null   object
#  15  entities.description.urls       92 non-null     object
#  16  entities.description.mentions   215 non-null    object
#  17  pinned_tweet_id                 554 non-null    float64
#  18  entities.description.hashtags   548 non-null    object
# dtypes: bool(2), float64(1), int64(5), object(11)
# memory usage: 163.5+ KB

# %%
prop_df.head()
# Out:
#                tweetid                                        userid  \
# 0  1161436140945195008                                     392352672
# 1   764273648496742400                                    4708503082
# 2   783000454963822592                                    4567368507
# 3   533615110539841538  xKG+qL9l7ousztBAlj8iQZm78XodFiOT+aZ9PrhzkUo=
# 4   511880965892087808  xBo+HezLTB78P+7p8upU8pqHohl9wdTT1yGUaJWa2ls=
#
#                               user_display_name  \
# 0                                  نجديه عذيه .
# 1      ْ‏ོ جود العبداللّهہ|| ོالتنبيهات ما توصل
# 2                            أملي بالله كبير^_^
# 3  xKG+qL9l7ousztBAlj8iQZm78XodFiOT+aZ9PrhzkUo=
# 4  xBo+HezLTB78P+7p8upU8pqHohl9wdTT1yGUaJWa2ls=
#
#                                user_screen_name  \
# 0                                       Ksa_FO1
# 1                                         j06__
# 2                                    khoo23khoo
# 3  xKG+qL9l7ousztBAlj8iQZm78XodFiOT+aZ9PrhzkUo=
# 4  xBo+HezLTB78P+7p8upU8pqHohl9wdTT1yGUaJWa2ls=
#
#            user_reported_location  \
# 0                نجد العذيه للدعم
# 1                            None
# 2  ومازال حسن ظني بك يا ربُ جميلٌ
# 3       في جنة الخلد ان شاء الله
# 4                            None
#
#                             user_profile_description  follower_count  \
# 0  مابادل اقل من ٥ الاف ولا أقبل المقدم بدون طلب ...           70616
# 1  ‏‏‏‏‏‏‏‏‏‏‏إنه يستجيب منذُ أن دعوُت ولگِن يُدب...           60061
# 2  ❇️اللهم أسترني فوق الأرض و تحت الأرض ويوم العر...           15244
# 3  حساب خاص صدقه جاريه للمرحوم بإذن الله وليد مشع...             282
# 4  ‏‏‏‏‏‏‏بكالوريوس التربية في الآداب\nجامعة المل...            2422
#
#    following_count  account_creation_date  \
# 0            52577          1318723200000
# 1             2617          1451865600000
# 2             8957          1450742400000
# 3               14          1362268800000
# 4              509          1338940800000
#
#                                           tweet_text  is_retweet  quote_count  \
# 0  RT @GROB_07: #حـسـآب_تـمــيزة_بـتـفـاعـل 💫\n⠀┈...        True            0
# 1  اللهم اكثر من امثالي ليعم الخير و تعم السعادة ...       False            0
# 2  RT @Ana5lod: @mohommad120\n#بصائر_مع_محمد\n\n١...        True            0
# 3  إن هذه القبور مملوءة ظلمة على أهلها وإن الله ع...       False            0
# 4  (يا قومنا أجيبوا داعي الله وآمنوا به يغفر لكم ...       False            0
#
#    reply_count  like_count  retweet_count  hashtags  urls  user_mentions  \
# 0            0           0              0         3     0              2
# 1            0           0              0         1     0              0
# 2            0           0              0         1     0              3
# 3            0           0              1         1     0              0
# 4            0           0              0         1     1              0
#
#                                                 text
# 0  RT : حـسـآب تـمــيزة بـتـفـاعـل ⠀┈┉━◈♔♚♔◈━┅┄ ن...
# 1  اللهم اكثر من امثالي ليعم الخير و تعم السعادة ...
# 2  RT : بصائر مع محمد ١ النيه،إزالةالموانع،الوضوء...
# 3  إن هذه القبور مملوءة ظلمة على أهلها وإن الله ع...
# 4  (يا قومنا أجيبوا داعي الله وآمنوا به يغفر لكم ...

# %%
prop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56000 entries, 0 to 55999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   56000 non-null  int64
#  1   userid                    56000 non-null  object
#  2   user_display_name         56000 non-null  object
#  3   user_screen_name          56000 non-null  object
#  4   user_reported_location    36366 non-null  object
#  5   user_profile_description  51749 non-null  object
#  6   follower_count            56000 non-null  int64
#  7   following_count           56000 non-null  int64
#  8   account_creation_date     56000 non-null  int64
#  9   tweet_text                56000 non-null  object
#  10  is_retweet                56000 non-null  bool
#  11  quote_count               56000 non-null  int64
#  12  reply_count               56000 non-null  int64
#  13  like_count                56000 non-null  int64
#  14  retweet_count             56000 non-null  int64
#  15  hashtags                  56000 non-null  int64
#  16  urls                      56000 non-null  int64
#  17  user_mentions             56000 non-null  int64
#  18  text                      56000 non-null  object
# dtypes: bool(1), int64(11), object(7)
# memory usage: 8.2+ MB

# %%
df2 = df2[df2.id.isin(df1["userid"])]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 664 entries, 0 to 1208
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   description                     664 non-null    object
#  1   name                            664 non-null    object
#  2   profile_image_url               664 non-null    object
#  3   url                             664 non-null    object
#  4   id                              664 non-null    int64
#  5   username                        664 non-null    object
#  6   created_at                      664 non-null    object
#  7   protected                       664 non-null    bool
#  8   verified                        664 non-null    bool
#  9   public_metrics.followers_count  664 non-null    int64
#  10  public_metrics.following_count  664 non-null    int64
#  11  public_metrics.tweet_count      664 non-null    int64
#  12  public_metrics.listed_count     664 non-null    int64
#  13  entities.url.urls               664 non-null    object
#  14  location                        629 non-null    object
#  15  entities.description.urls       47 non-null     object
#  16  entities.description.mentions   118 non-null    object
#  17  pinned_tweet_id                 282 non-null    float64
#  18  entities.description.hashtags   356 non-null    object
# dtypes: bool(2), float64(1), int64(5), object(11)
# memory usage: 94.7+ KB

# %%
df2.head()
# Out:
#                                          description                 name  \
# 0        حساب يهتم بأخبار الرياضة المحلية والعالمية.          واس الرياضي
# 1  حساب يهتم بالشأن العام على المستويين المحلي وا...            واس العام
# 2  أرقام شركة متخصصة في نشر المعلومات الاقتصادية ...  بوابة أرقام المالية
# 3  الحساب الرسمي | Official Account of King Faisa...     جامعة الملك فيصل
# 5  حساب يهتم بالأخبار التي تعزز جميع جوانب جودة ا...      واس جودة الحياة
#
#                                    profile_image_url                      url  \
# 0  https://pbs.twimg.com/profile_images/131274593...  https://t.co/71DZXnWjwI
# 1  https://pbs.twimg.com/profile_images/151794435...  https://t.co/zMWBLahSfG
# 2  https://pbs.twimg.com/profile_images/133080027...  https://t.co/rRX3PrBugu
# 3  https://pbs.twimg.com/profile_images/149866758...  https://t.co/hDhCttbgRW
# 5  https://pbs.twimg.com/profile_images/131274260...  https://t.co/upsHZJIL6y
#
#                     id        username                created_at  protected  \
# 0  1171062925488001025        SPA_Spor  2019-09-09T14:09:06.000Z      False
# 1  1171056150999158791      SPAregions  2019-09-09T13:42:06.000Z      False
# 2             30627754          Argaam  2009-04-12T09:21:19.000Z      False
# 3            208523378    KFUniversity  2010-10-27T12:46:19.000Z      False
# 5  1171057673598623744  SPAqualitylife  2019-09-09T13:48:21.000Z      False
#
#    verified  public_metrics.followers_count  public_metrics.following_count  \
# 0      True                          158216                               8
# 1      True                         2165525                               8
# 2      True                          544108                               7
# 3      True                          274829                              19
# 5      True                          176606                               8
#
#    public_metrics.tweet_count  public_metrics.listed_count  \
# 0                       18252                          493
# 1                       52420                         2031
# 2                      182223                         2856
# 3                       20205                          403
# 5                        6045                          522
#
#                                    entities.url.urls  \
# 0  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 1  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 2  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 3  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
# 5  [{'start': 0, 'end': 23, 'url': 'https://t.co/...
#
#                         location  \
# 0                            NaN
# 1                         الرياض
# 2        Kingdom of Saudi Arabia
# 3  Ahsa, Kingdom of Saudi Arabia
# 5                            NaN
#
#                            entities.description.urls  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'start': 114, 'end': 137, 'url': 'https://t....
# 3                                                NaN
# 5                                                NaN
#
#                        entities.description.mentions  pinned_tweet_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  [{'start': 157, 'end': 168, 'username': 'Argaa...              NaN
# 3                                                NaN     1.559553e+18
# 5                                                NaN              NaN
#
#   entities.description.hashtags
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 5                           NaN

# %%
names = []
handles = []
locations = []
bios = []
followers = []
following = []
creation_dates = []


for user in df1.userid.values:
    user_df = df2[df2.id == user]
    if len(user_df) == 0:
        names.append(None)
        handles.append(None)
        locations.append(None)
        bios.append(None)
        followers.append(None)
        following.append(None)
        creation_dates.append(None)
        continue
    names.append(user_df.loc[:, "name"].values[0])
    handles.append(user_df.loc[:, "username"].values[0])
    creation_dates.append(user_df.loc[:, "created_at"].values[0])
    locations.append(user_df.loc[:, "location"].values[0])
    bios.append(user_df.loc[:, "description"].values[0])
    followers.append(
        user_df.loc[:, "public_metrics.followers_count"].values[0])
    following.append(
        user_df.loc[:, "public_metrics.following_count"].values[0])

df1["user_display_name"] = names
df1["user_screen_name"] = handles
df1["user_reported_location"] = locations
df1["user_profile_description"] = bios
df1["follower_count"] = followers
df1["following_count"] = following
df1["account_creation_date"] = creation_dates

df1.head()
# Out:
#         tweetid                                         tweet_text  \
# 0  1.452250e+18  سمو رئيس اللجنة الأولمبية السعودية  الأمير عبد...
# 1  1.444422e+18  تركي آل الشيخ يوقّع روايته الأولى في #معرض_الر...
# 2  1.413105e+18  رئيس "هيئة الترفيه": قطاع الترفيه سيكون منافسا...
# 3  1.396870e+18  الرئيس المصري يستقبل المستشار تركي آل الشيخ.\n...
# 4  1.387807e+18  🎥 \nالشيخ منصور بن زايد آل نهيان يستقبل سمو ال...
#
#                  tweet_time        userid  \
# 0  2021-10-24T12:26:07.000Z  1.171063e+18
# 1  2021-10-02T21:59:59.000Z  1.171056e+18
# 2  2021-07-08T11:59:34.000Z  3.062775e+07
# 3  2021-05-24T16:43:45.000Z  1.171056e+18
# 4  2021-04-29T16:34:16.000Z  1.171063e+18
#
#                                                 urls  \
# 0  [{'start': 255, 'end': 278, 'url': 'https://t....
# 1  [{'start': 65, 'end': 88, 'url': 'https://t.co...
# 2  [{'start': 178, 'end': 201, 'url': 'https://t....
# 3  [{'start': 45, 'end': 68, 'url': 'https://t.co...
# 4  [{'start': 116, 'end': 139, 'url': 'https://t....
#
#                                             hashtags  retweet_count  \
# 0   [{'start': 244, 'end': 254, 'tag': 'واس_رياضي'}]            4.0
# 1  [{'start': 37, 'end': 63, 'tag': 'معرض_الرياض_...           71.0
# 2  [{'start': 105, 'end': 112, 'tag': 'عقارات'}, ...           20.0
# 3       [{'start': 69, 'end': 77, 'tag': 'واس_عام'}]          321.0
# 4   [{'start': 105, 'end': 115, 'tag': 'واس_رياضي'}]            3.0
#
#    reply_count  like_count  quote_count user_mentions  is_retweet  \
# 0          1.0         4.0          0.0           NaN       False
# 1        174.0       177.0         54.0           NaN       False
# 2         45.0        31.0          3.0           NaN       False
# 3        105.0       978.0          9.0           NaN       False
# 4          1.0         3.0          0.0           NaN       False
#
#      user_display_name user_screen_name   user_reported_location  \
# 0          واس الرياضي         SPA_Spor                      NaN
# 1            واس العام       SPAregions                   الرياض
# 2  بوابة أرقام المالية           Argaam  Kingdom of Saudi Arabia
# 3            واس العام       SPAregions                   الرياض
# 4          واس الرياضي         SPA_Spor                      NaN
#
#                             user_profile_description  follower_count  \
# 0        حساب يهتم بأخبار الرياضة المحلية والعالمية.          158216
# 1  حساب يهتم بالشأن العام على المستويين المحلي وا...         2165525
# 2  أرقام شركة متخصصة في نشر المعلومات الاقتصادية ...          544108
# 3  حساب يهتم بالشأن العام على المستويين المحلي وا...         2165525
# 4        حساب يهتم بأخبار الرياضة المحلية والعالمية.          158216
#
#    following_count     account_creation_date
# 0                8  2019-09-09T14:09:06.000Z
# 1                8  2019-09-09T13:42:06.000Z
# 2                7  2009-04-12T09:21:19.000Z
# 3                8  2019-09-09T13:42:06.000Z
# 4                8  2019-09-09T14:09:06.000Z

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9787 entries, 0 to 9791
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   9787 non-null   float64
#  1   tweet_text                9787 non-null   object
#  2   tweet_time                9787 non-null   object
#  3   userid                    9787 non-null   float64
#  4   urls                      8689 non-null   object
#  5   hashtags                  9449 non-null   object
#  6   retweet_count             9787 non-null   float64
#  7   reply_count               9787 non-null   float64
#  8   like_count                9787 non-null   float64
#  9   quote_count               9787 non-null   float64
#  10  user_mentions             1233 non-null   object
#  11  is_retweet                9787 non-null   bool
#  12  user_display_name         9787 non-null   object
#  13  user_screen_name          9787 non-null   object
#  14  user_reported_location    8769 non-null   object
#  15  user_profile_description  9787 non-null   object
#  16  follower_count            9787 non-null   int64
#  17  following_count           9787 non-null   int64
#  18  account_creation_date     9787 non-null   object
# dtypes: bool(1), float64(6), int64(2), object(10)
# memory usage: 1.4+ MB

# %%
df1["urls"] = [
    len(eval(urls)) if not pd.isna(urls) and not urls.isdigit() else 0 for urls in df1["urls"].values
]
df1["hashtags"] = [
    len(eval(hashtags)) if not pd.isna(hashtags) else 0
    for hashtags in df1["hashtags"].values
]
df1["user_mentions"] = [
    len(eval(mentions)) if not pd.isna(mentions) else 0
    for mentions in df1["user_mentions"].values
]

# %%
df1.head()
# Out:
#         tweetid                                         tweet_text  \
# 0  1.452250e+18  سمو رئيس اللجنة الأولمبية السعودية  الأمير عبد...
# 1  1.444422e+18  تركي آل الشيخ يوقّع روايته الأولى في #معرض_الر...
# 2  1.413105e+18  رئيس "هيئة الترفيه": قطاع الترفيه سيكون منافسا...
# 3  1.396870e+18  الرئيس المصري يستقبل المستشار تركي آل الشيخ.\n...
# 4  1.387807e+18  🎥 \nالشيخ منصور بن زايد آل نهيان يستقبل سمو ال...
#
#                  tweet_time        userid  urls  hashtags  retweet_count  \
# 0  2021-10-24T12:26:07.000Z  1.171063e+18     4         1            4.0
# 1  2021-10-02T21:59:59.000Z  1.171056e+18     3         3           71.0
# 2  2021-07-08T11:59:34.000Z  3.062775e+07     1         6           20.0
# 3  2021-05-24T16:43:45.000Z  1.171056e+18     2         1          321.0
# 4  2021-04-29T16:34:16.000Z  1.171063e+18     1         1            3.0
#
#    reply_count  like_count  quote_count  user_mentions  is_retweet  \
# 0          1.0         4.0          0.0              0       False
# 1        174.0       177.0         54.0              0       False
# 2         45.0        31.0          3.0              0       False
# 3        105.0       978.0          9.0              0       False
# 4          1.0         3.0          0.0              0       False
#
#      user_display_name user_screen_name   user_reported_location  \
# 0          واس الرياضي         SPA_Spor                      NaN
# 1            واس العام       SPAregions                   الرياض
# 2  بوابة أرقام المالية           Argaam  Kingdom of Saudi Arabia
# 3            واس العام       SPAregions                   الرياض
# 4          واس الرياضي         SPA_Spor                      NaN
#
#                             user_profile_description  follower_count  \
# 0        حساب يهتم بأخبار الرياضة المحلية والعالمية.          158216
# 1  حساب يهتم بالشأن العام على المستويين المحلي وا...         2165525
# 2  أرقام شركة متخصصة في نشر المعلومات الاقتصادية ...          544108
# 3  حساب يهتم بالشأن العام على المستويين المحلي وا...         2165525
# 4        حساب يهتم بأخبار الرياضة المحلية والعالمية.          158216
#
#    following_count     account_creation_date
# 0                8  2019-09-09T14:09:06.000Z
# 1                8  2019-09-09T13:42:06.000Z
# 2                7  2009-04-12T09:21:19.000Z
# 3                8  2019-09-09T13:42:06.000Z
# 4                8  2019-09-09T14:09:06.000Z

# %%
def clean_tweet_text(text):
    """Process tweet text by removing links, mentions symbol, and hashtags symbol."""
    # links
    clean_text = re.sub(r"http\S+|t\.co/\S+", "", text)
    # mentions
    clean_text = re.sub(r"@\w+", "", clean_text)
    # hashtags
    clean_text = re.sub(r"#", "", clean_text)
    clean_text = re.sub(r"_", " ", clean_text)
    # tashqeel - from @bakriano
    clean_text = re.sub(r"[\u0617-\u061A\u064B-\u0652]", "", clean_text)
    # emojis
    clean_text = emoji.replace_emoji(clean_text, replace="")
    # remove new lines and normalize white spaces
    clean_text = re.sub(r"\s+", " ", clean_text)
    # stemming the text
    # clean_text = stemmer.stem(clean_text)
    return clean_text.strip()

# %%
df1["text"] = df1.tweet_text.apply(clean_tweet_text)
df1.head()
# Out:
#         tweetid                                         tweet_text  \
# 0  1.452250e+18  سمو رئيس اللجنة الأولمبية السعودية  الأمير عبد...
# 1  1.444422e+18  تركي آل الشيخ يوقّع روايته الأولى في #معرض_الر...
# 2  1.413105e+18  رئيس "هيئة الترفيه": قطاع الترفيه سيكون منافسا...
# 3  1.396870e+18  الرئيس المصري يستقبل المستشار تركي آل الشيخ.\n...
# 4  1.387807e+18  🎥 \nالشيخ منصور بن زايد آل نهيان يستقبل سمو ال...
#
#                  tweet_time        userid  urls  hashtags  retweet_count  \
# 0  2021-10-24T12:26:07.000Z  1.171063e+18     4         1            4.0
# 1  2021-10-02T21:59:59.000Z  1.171056e+18     3         3           71.0
# 2  2021-07-08T11:59:34.000Z  3.062775e+07     1         6           20.0
# 3  2021-05-24T16:43:45.000Z  1.171056e+18     2         1          321.0
# 4  2021-04-29T16:34:16.000Z  1.171063e+18     1         1            3.0
#
#    reply_count  like_count  quote_count  user_mentions  is_retweet  \
# 0          1.0         4.0          0.0              0       False
# 1        174.0       177.0         54.0              0       False
# 2         45.0        31.0          3.0              0       False
# 3        105.0       978.0          9.0              0       False
# 4          1.0         3.0          0.0              0       False
#
#      user_display_name user_screen_name   user_reported_location  \
# 0          واس الرياضي         SPA_Spor                      NaN
# 1            واس العام       SPAregions                   الرياض
# 2  بوابة أرقام المالية           Argaam  Kingdom of Saudi Arabia
# 3            واس العام       SPAregions                   الرياض
# 4          واس الرياضي         SPA_Spor                      NaN
#
#                             user_profile_description  follower_count  \
# 0        حساب يهتم بأخبار الرياضة المحلية والعالمية.          158216
# 1  حساب يهتم بالشأن العام على المستويين المحلي وا...         2165525
# 2  أرقام شركة متخصصة في نشر المعلومات الاقتصادية ...          544108
# 3  حساب يهتم بالشأن العام على المستويين المحلي وا...         2165525
# 4        حساب يهتم بأخبار الرياضة المحلية والعالمية.          158216
#
#    following_count     account_creation_date  \
# 0                8  2019-09-09T14:09:06.000Z
# 1                8  2019-09-09T13:42:06.000Z
# 2                7  2009-04-12T09:21:19.000Z
# 3                8  2019-09-09T13:42:06.000Z
# 4                8  2019-09-09T14:09:06.000Z
#
#                                                 text
# 0  سمو رئيس اللجنة الأولمبية السعودية الأمير عبدا...
# 1  تركي آل الشيخ يوقع روايته الأولى في معرض الريا...
# 2  رئيس "هيئة الترفيه": قطاع الترفيه سيكون منافسا...
# 3  الرئيس المصري يستقبل المستشار تركي آل الشيخ. و...
# 4  الشيخ منصور بن زايد آل نهيان يستقبل سمو الأمير...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9787 entries, 0 to 9791
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   9787 non-null   float64
#  1   tweet_text                9787 non-null   object
#  2   tweet_time                9787 non-null   object
#  3   userid                    9787 non-null   float64
#  4   urls                      9787 non-null   int64
#  5   hashtags                  9787 non-null   int64
#  6   retweet_count             9787 non-null   float64
#  7   reply_count               9787 non-null   float64
#  8   like_count                9787 non-null   float64
#  9   quote_count               9787 non-null   float64
#  10  user_mentions             9787 non-null   int64
#  11  is_retweet                9787 non-null   bool
#  12  user_display_name         9787 non-null   object
#  13  user_screen_name          9787 non-null   object
#  14  user_reported_location    8769 non-null   object
#  15  user_profile_description  9787 non-null   object
#  16  follower_count            9787 non-null   int64
#  17  following_count           9787 non-null   int64
#  18  account_creation_date     9787 non-null   object
#  19  text                      9787 non-null   object
# dtypes: bool(1), float64(6), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
prop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56000 entries, 0 to 55999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   56000 non-null  int64
#  1   userid                    56000 non-null  object
#  2   user_display_name         56000 non-null  object
#  3   user_screen_name          56000 non-null  object
#  4   user_reported_location    36366 non-null  object
#  5   user_profile_description  51749 non-null  object
#  6   follower_count            56000 non-null  int64
#  7   following_count           56000 non-null  int64
#  8   account_creation_date     56000 non-null  int64
#  9   tweet_text                56000 non-null  object
#  10  is_retweet                56000 non-null  bool
#  11  quote_count               56000 non-null  int64
#  12  reply_count               56000 non-null  int64
#  13  like_count                56000 non-null  int64
#  14  retweet_count             56000 non-null  int64
#  15  hashtags                  56000 non-null  int64
#  16  urls                      56000 non-null  int64
#  17  user_mentions             56000 non-null  int64
#  18  text                      56000 non-null  object
# dtypes: bool(1), int64(11), object(7)
# memory usage: 8.2+ MB

# %%
df1 = df1[prop_df.columns]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9787 entries, 0 to 9791
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tweetid                   9787 non-null   float64
#  1   userid                    9787 non-null   float64
#  2   user_display_name         9787 non-null   object
#  3   user_screen_name          9787 non-null   object
#  4   user_reported_location    8769 non-null   object
#  5   user_profile_description  9787 non-null   object
#  6   follower_count            9787 non-null   int64
#  7   following_count           9787 non-null   int64
#  8   account_creation_date     9787 non-null   object
#  9   tweet_text                9787 non-null   object
#  10  is_retweet                9787 non-null   bool
#  11  quote_count               9787 non-null   float64
#  12  reply_count               9787 non-null   float64
#  13  like_count                9787 non-null   float64
#  14  retweet_count             9787 non-null   float64
#  15  hashtags                  9787 non-null   int64
#  16  urls                      9787 non-null   int64
#  17  user_mentions             9787 non-null   int64
#  18  text                      9787 non-null   object
# dtypes: bool(1), float64(6), int64(5), object(7)
# memory usage: 1.4+ MB

# %%
df1.to_json("../data/processed/genuine_univ.json")
